# %% [markdown]
# <a href="https://colab.research.google.com/github/iamaks1993/doctr-text-recognition/blob/main/quickstarts/Text_recogization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### Copyright 2025 Google LLC.

# %%
pip install python-doctr

# %%
pip install torch torchvision torchaudio

# %%
pip install mplcursors # For show image

# %%
from doctr.io import DocumentFile
from doctr.models import ocr_predictor

# %%
model = ocr_predictor(pretrained=True)

# %%
document = DocumentFile.from_images('plaid_c150.jpg')

# %%
result = model(document)

# %%
result.show()

# %%
json_response = result.export()

# %%
json_response
# Out:
# {'pages': [{'page_idx': 0,
#    'dimensions': (940, 640),
#    'orientation': {'value': None, 'confidence': None},
#    'language': {'value': None, 'confidence': None},
#    'blocks': []}]}
